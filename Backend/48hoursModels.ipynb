# %%
import os
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import boto3
from smart_open import smart_open
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### Loading Data From Bucket

# %%
#Data Prep for Prophet
#AWS Credentials
aws_access = 'AKIA3OQDEGY5IF2353GU'
aws_secret_access = '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'

#Creating S3 client
s3 = boto3.client('s3', aws_access_key_id = aws_access, aws_secret_access_key = aws_secret_access)

#Bucket Directory
bucket = 'electricitydemandforecasting'
file_actuals = 'Data/actuals.csv'
file_forecasts = 'Data/forecasts.csv'


file_path_actuals = 's3://{}:{}@{}/{}'.format(aws_access, aws_secret_access, bucket, file_actuals)

file_path_forecast = 's3://{}:{}@{}/{}'.format(aws_access, aws_secret_access, bucket, file_forecasts)

#Train / actuals dataframe
df_train = pd.read_csv(smart_open(file_path_actuals))
df_train['Time'] = pd.to_datetime(df_train['Time'])

#Test / forecasts dataframe
df_test = pd.read_csv(smart_open(file_path_forecast))
df_test['Time'] = pd.to_datetime(df_test['Time'])


# df_train_no_time = df_train
df_train_no_time = df_train.drop(columns = 'Time')

# df_test_no_time = df_test
df_test_no_time = df_test.drop(columns = 'Time')

# %% [markdown]
# ### Fixing empty

# %%
def fill_missing_values(df):
    x = np.where(pd.isnull(df))

    for i in range(len(x[0])):
        if x[1][i] == 0:
            ts = df.iloc[x[0][i] - 1, 0]
            new_ts = ts + pd.Timedelta(hours=1)
            df.iloc[x[0][i], x[1][i]] = new_ts
        else:
            temp = 0
            for j in range(10, 0, -1):
                temp += df.iloc[x[0][i] - j, x[1][i]]
            average = temp / 10
            df.iloc[x[0][i], x[1][i]] = average
    return df

df_test = fill_missing_values(df_test)
df_train = fill_missing_values(df_train)

# %% [markdown]
# ### Normalising Values

# %%
# # Create a Min-Max scaler
# scaler = MinMaxScaler()

# # List of features to normalize (replace these with your feature column names)
# feature_columns = ['Load (kW)', 'Pressure_kpa', 'Cloud Cover (%)', 'Humidity (%)', 'Temperature (C) ', 'Wind Direction (deg)', 'Wind Speed (kmh)']
# feature_columns_forecast = ['Cloud Cover (%)', 'Pressure_kpa', 'Temperature (C) ', 'Wind Direction (deg)', 'Wind Speed (kmh)']

# # Normalize each feature and add them back to the DataFrame
# for column in feature_columns:
#     df_train[column] = scaler.fit_transform(df_train[[column]])

# for column in feature_columns_forecast:
#     df_test[column] = scaler.fit_transform(df_test[[column]])

# %% [markdown]
# ### combine dataset

# %%
def combine_rows_with_different_attribute_names(df, df_test):
    combined_data_list = []

    # start at 0, stop 168 + 1 rows before end, jump by 24 hours / 1 day.
    for i in range(0, len(df_test) - (168 + 1), 24):
        combined_data = {}
        
        if i + 168 + 24 >= (len(df_test)):
            break
        
        for j in range(168):
            row = df.iloc[i + j]

            # Iterate over columns and update column names
            for col, val in row.items():
                combined_data[f"{col}_date{j+1}"] = val
        
        # Append the combined data dictionary to the list
        
        for j in range(48):
            # if i + j + 168 >= (len(df_test) - 1):
            #     break
            row = df_test.iloc[i + j + 168]
            
            for col, val in row.items():
                combined_data[f"{col}_test_date{j+1}"] = val
            
            
        combined_data_list.append(combined_data)

    # Convert the list of dictionaries into a DataFrame
    combined_df = pd.DataFrame(combined_data_list)

    return combined_df

# Example usage:
# Assuming you have a DataFrame named df_train
formatted_data = combine_rows_with_different_attribute_names(df_train, df_test)

# %% [markdown]
# ### the actual values

# %%
def actual(df_train):
    # Initializing the list to store the combined load data for every two overlapping days
    overlapping_grouped_data = []

    # Iterate over the dataframe in steps of 24 hours to create overlapping groups of 48 hours (2 days)
    for i in range(0, len(df_train) - 48 + 1, 24):
        two_day_data = df_train.iloc[i:i+48]['Load (kW)'].values
        overlapping_grouped_data.append(two_day_data)

    # Convert the grouped data into a dataframe
    combined_load_df = pd.DataFrame(overlapping_grouped_data)

    # Drop the first 7 rows from overlapping_combined_load_df
    combined_load_df = combined_load_df.iloc[7:]

    return combined_load_df

actual_data = actual(df_train)

# %% [markdown]
# ### Calculate Metrics

# %%
def calculate_metrics(predictions, actuals):
    
    predicted_load = np.array(predictions)
    actual_load = np.array(actuals)

    # Calculate the MAE for the current sublist
    mae = mean_absolute_error(actual_load, predicted_load)
    
    # Calculate the RMSE for the current sublist
    mse = mean_squared_error(actual_load, predicted_load)
    rmse = np.sqrt(mse)
    
    # Calculate the MAPE for the current sublist
    mape = np.mean(np.abs((actual_load - predicted_load) / actual_load)) * 100
    
    # Calculate the R-squared (R²) for the current sublist
    r_squared = r2_score(actual_load, predicted_load)
    
    if mae != "":
        return mae, rmse, mape, r_squared

    else:
        print("Variable 'a' is not defined.")

# %% [markdown]
# ### Graph for the last two values

# %%
def graph(formatted_data, predictions, actuals, title=None, filename=None):
    
    two_values = pd.DataFrame({
        "Time" : formatted_data.filter(like="Time").iloc[-1].tail(48).values,
        "predictions" : predictions,
        "actuals" : actuals
    })
    
    # Adjusting the plot settings
    fig, ax = plt.subplots(figsize=(18, 6))
    
    # Create a line plot for 'predictions' in blue with a thicker line
    ax.plot(two_values['Time'], two_values['predictions'], color='royalblue', linewidth=2, label='Predictions')
    
    # Create a line plot for 'actuals' in red with larger markers
    ax.plot(two_values['Time'], two_values['actuals'], color='orangered', marker='o', markersize=6, linestyle='-', label='Actuals')
    
    ax.set_xlabel('Time')
    ax.set_ylabel('Values')
    ax.tick_params('y')
    
    # Display all x-axis labels
    ax.set_xticks(two_values['Time'])
    ax.set_xticklabels(two_values['Time'].dt.strftime('%Y-%m-%d %H:%M:%S'), rotation=45, fontsize=10)
    
    # Removing scientific notation
    ax.ticklabel_format(style='plain', axis='y')
    
    # Set the title and legend
    if title:
        plt.title(title, fontsize=14, fontweight='bold')
    ax.legend(loc='lower right', fontsize=10, framealpha=1, facecolor='white')
    
    plt.grid(True, linestyle='--', alpha=0.5)
    
    # Adjust the layout
    plt.tight_layout()
    
    # Check if filename is provided and then save
    if filename:
        save_path = os.path.join('..', 'Frontend', 'media', filename + '.png')
        plt.savefig(save_path, dpi=300)

    plt.show()

# %% [markdown]
# ### Naive model

# %%
def naive(formatted_data,actual_data):
    """
    :Input: 
        :data: The entire dataset of batches.
        
    For this algorithm, go over each batch, create a list of predctions,
    compare these predictions to the predictions to actuals, which can be done through the 
    next row which introduce the data for the next two days.
    """

    predictions = []
    actuals = []
    for index, row in formatted_data.iterrows():
        predictions.append([])
        actuals.append([])
        for i in range(121, 169):
            column_load = f"Load (kW)_date{i}"
            column_time = f"Time_date{i}"
            
            # predictions[index] = [load, time of load used to make prediction]
            # The load above is for the time to the right plus two days.
            
            # predictions[index].append([row[column_load], row[column_time]])
            
            # Just Predicted Load
            predictions[index].append(row[column_load]) 

    
    actuals = actual_data.values
    predictions = predictions[-1]
    actuals = actuals[-1]

    return predictions, actuals

    
n_predictions, n_actuals = naive(formatted_data,actual_data)

# %%
def naive(formatted_data,actual_data):
    """
    :Input: 
        :data: The entire dataset of batches.
        
    For this algorithm, go over each batch, create a list of predctions,
    compare these predictions to the predictions to actuals, which can be done through the 
    next row which introduce the data for the next two days.
    """

    predictions = []
    actuals = []
    for index, row in formatted_data.iterrows():
        predictions.append([])
        actuals.append([])
        column_load = f"Load (kW)_date168"
        for i in range(48):
            predictions[index].append(row[column_load]) 

    
    actuals = actual_data.values

    predictions = predictions[-1]
    actuals = actuals[-1]

    return predictions, actuals

    
n_predictions, n_actuals = naive(formatted_data,actual_data)

# %%
print("Naive:")
n_mae,n_rmse,n_mape,n_r2 = calculate_metrics(n_predictions, n_actuals)

print(f"MAE: {n_mae}")
print(f"RMSE: {n_rmse}")
print(f"MAPE: {n_mape}")
print(f"R-squared (R²): {n_r2}")
# Out:
# Naive:
# MAE: 0.14736973147976123
# RMSE: 0.1796591043435185
# MAPE: 38.89846021373454
# R-squared (R²): -0.798030867307358

# %%
graph(formatted_data, n_predictions, n_actuals, "Time Series Forecasting : Naive Model", 'model_naive')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-118-e2af1d379e30> in <module>
# ----> 1 graph(formatted_data, n_predictions, n_actuals, "Time Series Forecasting : Naive Model", 'model_naive')
#
# <ipython-input-114-5a7b228aa5b5> in graph(formatted_data, predictions, actuals, title, filename)
#      40     if filename:
#      41         save_path = os.path.join('..', 'Frontend', 'media', filename + '.png')
# ---> 42         plt.savefig(save_path, dpi=300)
#      43
#      44     plt.show()
#
# c:\Users\Ethan\anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# c:\Users\Ethan\anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# c:\Users\Ethan\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2208
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#    2212                     dpi=dpi,
#
# c:\Users\Ethan\anaconda3\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# c:\Users\Ethan\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     508         """
#     509         FigureCanvasAgg.draw(self)
# --> 510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     512             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# c:\Users\Ethan\anaconda3\lib\site-packages\matplotlib\image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1609         pil_kwargs.setdefault("format", format)
#    1610         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1611         image.save(fname, **pil_kwargs)
#    1612
#    1613
#
# c:\Users\Ethan\anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2167                 fp = builtins.open(filename, "r+b")
#    2168             else:
# -> 2169                 fp = builtins.open(filename, "w+b")
#    2170
#    2171         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '..\\Frontend\\media\\model_naive.png'

# %% [markdown]
# ### Random walk model

# %%
def random_walk_forecast(formatted_data,actual_data):
    """
    Generate random walk forecasts.
    """

    predictions = []
    actuals = []
    
    for index, row in formatted_data.iterrows():
        last_observed_value = row["Load (kW)_date168"]
        batch_predictions = [last_observed_value + np.random.normal(0, 0.1) for _ in range(48)]
        predictions.append(batch_predictions)
        
        # Extracting actuals with a two-row offset
        
    actuals = actual_data.values
            
    predictions = predictions[-1]
    actuals = actuals[-1]

    return predictions, actuals


rw_predictions, rw_actuals = random_walk_forecast(formatted_data,actual_data)

# %%
print("Random walk:")
rw_mae,rw_rmse,rw_mape,rw_r2 = calculate_metrics(rw_predictions, rw_actuals)

print(f"MAE: {rw_mae}")
print(f"RMSE: {rw_rmse}")
print(f"MAPE: {rw_mape}")
print(f"R-squared (R²): {rw_r2}")
# Out:
# Random walk:
# MAE: 0.16876859631712962
# RMSE: 0.21575870079685947
# MAPE: 49.33114545127821
# R-squared (R²): -1.5931958579992656

# %%
graph(formatted_data, rw_predictions, rw_actuals, "Time Series Forecasting : Random Walk Model", 'model_randomwalk')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-121-123fea53b6b1> in <module>
# ----> 1 graph(formatted_data, rw_predictions, rw_actuals, "Time Series Forecasting : Random Walk Model", 'model_randomwalk')
#
# <ipython-input-114-5a7b228aa5b5> in graph(formatted_data, predictions, actuals, title, filename)
#      40     if filename:
#      41         save_path = os.path.join('..', 'Frontend', 'media', filename + '.png')
# ---> 42         plt.savefig(save_path, dpi=300)
#      43
#      44     plt.show()
#
# c:\Users\Ethan\anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# c:\Users\Ethan\anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# c:\Users\Ethan\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2208
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#    2212                     dpi=dpi,
#
# c:\Users\Ethan\anaconda3\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# c:\Users\Ethan\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     508         """
#     509         FigureCanvasAgg.draw(self)
# --> 510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     512             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# c:\Users\Ethan\anaconda3\lib\site-packages\matplotlib\image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1609         pil_kwargs.setdefault("format", format)
#    1610         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1611         image.save(fname, **pil_kwargs)
#    1612
#    1613
#
# c:\Users\Ethan\anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2167                 fp = builtins.open(filename, "r+b")
#    2168             else:
# -> 2169                 fp = builtins.open(filename, "w+b")
#    2170
#    2171         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '..\\Frontend\\media\\model_randomwalk.png'

# %% [markdown]
# ### Lightgbm model

# %%
# Define a function to check for problematic characters in column names
def check_problematic_column_names(df):
    problematic_chars = ['[', ']', '{', '}', ':', '"', ',']
    problematic_columns = []

    # Iterate over each column name
    for column in df.columns:
        str_column = str(column)  # Convert column name to string
        for char in problematic_chars:
            if char in str_column:
                problematic_columns.append(str_column)
                break

    return problematic_columns

# Check both dataframes for problematic column names
formatted_problematic_columns = check_problematic_column_names(formatted_data)
actual_problematic_columns = check_problematic_column_names(actual_data)

print("Problematic columns in formatted_data:", formatted_problematic_columns)
print("Problematic columns in actual_data:", actual_problematic_columns)
# Out:
# Problematic columns in formatted_data: []
# Problematic columns in actual_data: []

# %%
def sanitize_column_names(df):
    # Convert all column names to string
    df.columns = df.columns.astype(str)
    
    # Replace or remove undesired characters
    df.columns = df.columns.str.replace('[\[\]{}:"\']', '_', regex=True)
    return df

# Use the function before feeding the data to LightGBM
formatted_data = sanitize_column_names(formatted_data)
actual_data = sanitize_column_names(actual_data)

# %%
def lightgbm(formatted_data, actual_data):
    # Removing columns related to "Time" from formatted_data
    features_without_time = formatted_data.drop(columns=[col for col in formatted_data.columns if 'Time' in col])
    features =features_without_time

    targets = actual_data
    # Splitting the data into training and validation sets (80% training, 20% validation)
    X_train, X_val, y_train_df, y_val_df = train_test_split(features, targets, test_size=0.1, shuffle=False)

    # Setting LightGBM parameters
    params = {
        'boosting_type': 'gbdt',
        'objective': 'regression',
        'metric': 'rmse',
        'num_leaves': 31,
        'learning_rate': 0.05,
        'feature_fraction': 0.5
    }

    num_round = 100

    models = []
    pred = []
    for column in y_train_df.columns:
        y_train = y_train_df[column].values
        y_val = y_val_df[column].values
        
        # Creating a LightGBM dataset
        train_dataset = lgb.Dataset(X_train, label=y_train)
        val_dataset = lgb.Dataset(X_val, label=y_val, reference=train_dataset)
        
        # Training the model
        bst = lgb.train(params, train_dataset, num_round, valid_sets= val_dataset, callbacks = [lgb.early_stopping(stopping_rounds=10)])
        
        # Storing the trained model
        models.append(bst)

        # Predicting on the validation set
        y_pred = bst.predict(X_val, num_iteration=bst.best_iteration)
        
        pred.append(y_pred)

    # Transposing the list
    pred = list(map(list, zip(*pred)))
    y_val_df = y_val_df.values

    pred = pred[-1]
    y_val_df = y_val_df[-1]

    return pred, y_val_df

lightgbm_predictions, lightgbm_actuals = lightgbm(formatted_data, actual_data)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036980 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.278125
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [47]	valid_0's rmse: 0.0147814
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032939 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.248673
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [37]	valid_0's rmse: 0.0160742
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026692 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.225431
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [31]	valid_0's rmse: 0.0160494
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027904 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.209233
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [30]	valid_0's rmse: 0.0168463
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026778 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.202071
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [25]	valid_0's rmse: 0.0168348
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029777 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.211002
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [33]	valid_0's rmse: 0.016778
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025949 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.232069
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [42]	valid_0's rmse: 0.0186929
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.024550 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.292927
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [40]	valid_0's rmse: 0.0251383
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027179 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.406863
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [56]	valid_0's rmse: 0.0376927
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025881 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.510697
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [51]	valid_0's rmse: 0.0482751
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.024022 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.571974
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [47]	valid_0's rmse: 0.0583263
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028266 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.591110
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [47]	valid_0's rmse: 0.06171
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.024247 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.589999
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [47]	valid_0's rmse: 0.0578733
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025887 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.579131
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [39]	valid_0's rmse: 0.0582294
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037591 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.588078
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [45]	valid_0's rmse: 0.0582302
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035107 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.582761
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [46]	valid_0's rmse: 0.0598752
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039659 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.567822
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [44]	valid_0's rmse: 0.0577963
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037546 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.535970
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [39]	valid_0's rmse: 0.0511561
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034671 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.498475
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [47]	valid_0's rmse: 0.0413374
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035064 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.454746
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [47]	valid_0's rmse: 0.0366451
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036247 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.410225
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [42]	valid_0's rmse: 0.0317003
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035228 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.377661
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [50]	valid_0's rmse: 0.0266621
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037364 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.344591
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [64]	valid_0's rmse: 0.0249573
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036109 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.310014
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [54]	valid_0's rmse: 0.0221802
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035628 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.278137
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [62]	valid_0's rmse: 0.0257932
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.041760 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.248690
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [35]	valid_0's rmse: 0.0248535
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034319 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.225451
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [35]	valid_0's rmse: 0.0236149
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.041483 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.209257
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [26]	valid_0's rmse: 0.0235648
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039405 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.202098
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [27]	valid_0's rmse: 0.0224532
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.085126 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.211031
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [31]	valid_0's rmse: 0.0214692
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038047 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.232094
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [42]	valid_0's rmse: 0.0234854
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038520 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.292964
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [46]	valid_0's rmse: 0.026677
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033940 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.406931
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [60]	valid_0's rmse: 0.0369035
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035640 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.510773
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [62]	valid_0's rmse: 0.0495658
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036547 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.572059
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [70]	valid_0's rmse: 0.056152
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036804 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.591207
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [55]	valid_0's rmse: 0.0592153
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.040408 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.590092
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [66]	valid_0's rmse: 0.0610355
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039141 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.579219
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [70]	valid_0's rmse: 0.0564062
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038434 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.588160
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [68]	valid_0's rmse: 0.0590575
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039350 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.582829
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [75]	valid_0's rmse: 0.0608842
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035963 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.567859
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [70]	valid_0's rmse: 0.061297
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.040381 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.535983
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [69]	valid_0's rmse: 0.0550506
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038600 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.498465
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [71]	valid_0's rmse: 0.0505978
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.040780 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.454707
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [54]	valid_0's rmse: 0.0400929
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.042794 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.410175
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [42]	valid_0's rmse: 0.0341208
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.040246 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.377608
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [56]	valid_0's rmse: 0.0312998
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037755 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.344530
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [79]	valid_0's rmse: 0.0269403
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.041858 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 310883
# [LightGBM] [Info] Number of data points in the train set: 1252, number of used features: 1416
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.309948
# Training until validation scores don't improve for 15 rounds
# Early stopping, best iteration is:
# [47]	valid_0's rmse: 0.0275097

# %%
print("Lightgbm Model")
lightgbm_mae,lightgbm_rmse,lightgbm_mape,lightgbm_r2 = calculate_metrics(lightgbm_predictions, lightgbm_actuals)

print(f"MAE: {lightgbm_mae}")
print(f"RMSE: {lightgbm_rmse}")
print(f"MAPE: {lightgbm_mape}")
print(f"R-squared (R²): {lightgbm_r2}")
# Out:
# Lightgbm Model
# MAE: 0.007264440192319278
# RMSE: 0.011423358163741636
# MAPE: 2.1993613872031563
# R-squared (R²): 0.9927308058227782

# %%
graph(formatted_data, lightgbm_predictions, lightgbm_actuals, "Time Series Forecasting : LightGBM Model", 'model_lightgbm')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-138-802648990d9a> in <module>
# ----> 1 graph(formatted_data, lightgbm_predictions, lightgbm_actuals, "Time Series Forecasting : LightGBM Model", 'model_lightgbm')
#
# <ipython-input-114-5a7b228aa5b5> in graph(formatted_data, predictions, actuals, title, filename)
#      40     if filename:
#      41         save_path = os.path.join('..', 'Frontend', 'media', filename + '.png')
# ---> 42         plt.savefig(save_path, dpi=300)
#      43
#      44     plt.show()
#
# c:\Users\Ethan\anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# c:\Users\Ethan\anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# c:\Users\Ethan\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2208
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#    2212                     dpi=dpi,
#
# c:\Users\Ethan\anaconda3\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# c:\Users\Ethan\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     508         """
#     509         FigureCanvasAgg.draw(self)
# --> 510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     512             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# c:\Users\Ethan\anaconda3\lib\site-packages\matplotlib\image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1609         pil_kwargs.setdefault("format", format)
#    1610         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1611         image.save(fname, **pil_kwargs)
#    1612
#    1613
#
# c:\Users\Ethan\anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2167                 fp = builtins.open(filename, "r+b")
#    2168             else:
# -> 2169                 fp = builtins.open(filename, "w+b")
#    2170
#    2171         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '..\\Frontend\\media\\model_lightgbm.png'

# %%
# Create a title that includes metrics
title_with_metrics = (
    f"Predictions vs Actuals\n"
    f"MAE: {lightgbm_mae:.2f} | RMSE: {lightgbm_rmse:.2f} | MAPE: {lightgbm_mape:.2f}% | R-squared: {lightgbm_r2:.2f}"
)

# Call the graph function with the calculated metrics included in the title
graph(formatted_data, lightgbm_predictions, lightgbm_actuals, title=title_with_metrics, filename=None)
